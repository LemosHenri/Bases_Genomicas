# %%
import pandas as pd
import numpy as np

# %%
# Leitura do dataframe contendo os dados gerais tratados
df = pd.read_csv('../Data/Culicidae/dados_tratados_todos_culicidae.csv')
df.head()
# Out:
#      SRA acc Biosample acc Bioproject acc  Taxonomia acc          Instrumento  \
# 0  DRR870143  SAMD01750741     PRJDB39421           7159  Illumina HiSeq 4000
# 1  DRR870142  SAMD01750740     PRJDB39421           7159  Illumina HiSeq 4000
# 2  DRR870141  SAMD01750739     PRJDB39421           7159  Illumina HiSeq 4000
# 3  DRR870140  SAMD01750738     PRJDB39421           7159  Illumina HiSeq 4000
# 4  DRR870139  SAMD01750737     PRJDB39421           7159  Illumina HiSeq 4000
#
#    Amostras  Bases  Tamanho      Organismo Estratégia         Recurso Seleção  \
# 0  25113835    7.5  2748.71  Aedes aegypti    RNA-Seq  Transcriptomic  Random
# 1  24795456    7.4  2700.24  Aedes aegypti    RNA-Seq  Transcriptomic  Random
# 2  22395959    6.7  2426.74  Aedes aegypti    RNA-Seq  Transcriptomic  Random
# 3  24092864    7.2  2642.57  Aedes aegypti    RNA-Seq  Transcriptomic  Random
# 4  23805015    7.1  2607.44  Aedes aegypti    RNA-Seq  Transcriptomic  Random
#
# ...

# %%
# Informações sobre o dataframe
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38149 entries, 0 to 38148
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SRA acc         38148 non-null  str
#  1   Biosample acc   38149 non-null  str
#  2   Bioproject acc  37543 non-null  str
#  3   Taxonomia acc   38149 non-null  int64
#  4   Instrumento     38149 non-null  str
#  5   Amostras        38149 non-null  int64
#  6   Bases           38149 non-null  float64
#  7   Tamanho         38149 non-null  float64
#  8   Organismo       37318 non-null  str
#  9   Estratégia      38149 non-null  str
#  10  Recurso         38149 non-null  str
#  11  Seleção         38149 non-null  str
#  12  Protocolo       2063 non-null   str
#  13  Criação         38149 non-null  str
# dtypes: float64(2), int64(2), str(10)
# memory usage: 4.1 MB
# None

# %%
print('Tamanho de armazenamento total (MB):', df['Tamanho'].sum())
print('Tamanho de armazenamento total (GB):', round(df['Tamanho'].sum() / 1e3, 2))
print('Tamanho de armazenamento total (TB):', round(df['Tamanho'].sum() / 1e6, 2))
# Out:
# Tamanho de armazenamento total (MB): 73917025.56
# Tamanho de armazenamento total (GB): 73917.03
# Tamanho de armazenamento total (TB): 73.92

# %%
print('Número total de base pairs (Gb):', df['Bases'].sum())
# Out:
# Número total de base pairs (Gb): 180560.2

# %%
df['Estratégia'].value_counts()
# Out:
# Estratégia
# RAD-Seq                12276
# AMPLICON                8269
# RNA-Seq                 7707
# WGS                     6097
# miRNA-Seq                944
# WGA                      776
# OTHER                    704
# Targeted-Capture         472
# ChIP-Seq                 162
# WXS                      155
# GBS                      115
# ncRNA-Seq                114
# RIP-Seq                  111
# ATAC-seq                  79
# Hi-C                      72
# CLONE                     34
# Synthetic-Long-Read       24
# Bisulfite-Seq             21
# FL-cDNA                   11
# ssRNA-seq                  4
# EST                        1
# FINISHING                  1
# Name: count, dtype: int64

# %%
df['Recurso'].value_counts()
# Out:
# Recurso
# Genomic                       27039
# Transcriptomic                 7993
# Metagenomic                    2211
# Other                           321
# Metatranscriptomic              281
# Viral Rna                       174
# Transcriptomic Single Cell      124
# Synthetic                         6
# Name: count, dtype: int64

# %%
df['Seleção'].value_counts()
# Out:
# Seleção
# Pcr                          10173
# Reduced Representation        6858
# Random                        5790
# Restriction Digest            4970
# Cdna                          2331
# Polya                         1410
# Size Fractionation            1238
# Other                         1229
# Unspecified                    887
# Oligo-Dt                       788
# Random Pcr                     721
# Rt-Pcr                         687
# Hybrid Selection               387
# 5-Methylcytidine Antibody      319
# Cdna_Randompriming             155
# Inverse Rrna                    78
# Chip                            70
# Cdna_Oligo_Dt                   36
# Dnase                           11
# Msll                             9
# Mda                              1
# Race                             1
# Name: count, dtype: int64

# %%
df['Instrumento'].value_counts()
# Out:
# Instrumento
# Illumina MiSeq                  5650
# Illumina NovaSeq X              5403
# Illumina NovaSeq 6000           4754
# Illumina HiSeq 2000             4127
# Illumina HiSeq 4000             2870
# Illumina HiSeq 2500             2393
# NextSeq 500                     2182
# HiSeq X Ten                     1714
# NextSeq 2000                    1042
# MinION                           885
# Illumina HiSeq 3000              769
# Ion Torrent S5                   687
# Illumina NovaSeq X Plus          662
# NextSeq 550                      659
# AB 310 Genetic Analyzer          551
# PacBio RS II                     433
# GridION                          426
# BGISEQ-500                       419
# Illumina Genome Analyzer IIx     381
# Illumina HiSeq 1000              356
# NextSeq 1000                     292
# Illumina iSeq 100                273
# PromethION                       217
# Illumina Genome Analyzer II      199
# Illumina MiniSeq                 148
# ...
